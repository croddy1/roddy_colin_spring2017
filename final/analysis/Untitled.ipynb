# %% [markdown]
# # Sandbox

# %%
import pandas as pd
import numpy as np
from pandas import DataFrame
from datetime import datetime,date,timedelta
import seaborn as sns
import os

# %%
#dataPath = os.getcwd()+'/ml-latest-small/ratings.csv'
cityTemp = pd.read_csv('../data/GlobalLandTemperatures/GlobalLandTemperaturesByCity.csv')
stateTemp = pd.read_csv('../data/GlobalLandTemperatures/GlobalLandTemperaturesByState.csv')
wdi = pd.read_csv('../data/WDI_csv/WDIData.csv')
# movies2 = pd.read_csv('../Lecture-09/ml-latest-small/movies.csv')
# links = pd.read_csv('../Lecture-09/ml-latest-small/movies.csv')
# tags = pd.read_csv('../Lecture-09/ml-latest-small/movies.csv')

# %%
pop = pd.read_csv('../data/population/totalpop.csv')
# Out:
# ---------------------------------------------------------------------------
# CParserError                              Traceback (most recent call last)
# <ipython-input-38-d0a586706775> in <module>()
# ----> 1 pop = pd.read_csv('../data/population/totalpop.csv')
#
# ...

# %%
pop.head()
# Out:
#   Country Code                     Region          IncomeGroup  \
# 0          ABW  Latin America & Caribbean          High income
# 1          AFG                 South Asia           Low income
# 2          AGO         Sub-Saharan Africa  Upper middle income
# 3          ALB      Europe & Central Asia  Upper middle income
# 4          AND      Europe & Central Asia          High income
#
#                                         SpecialNotes    TableName  Unnamed: 5
# 0  SNA data for 2000-2011 are updated from offici...        Aruba         NaN
# 1  Fiscal year end: March 20; reporting period fo...  Afghanistan         NaN
# 2  April 2013 database update: Based on IMF data,...       Angola         NaN
# 3                                                NaN      Albania         NaN
# 4  The base year has changed to 2000. Price valua...      Andorra         NaN

# %%
wdi.head()
# Out:
#   Country Code   Short Name   Table Name                     Long Name  \
# 0          ABW        Aruba        Aruba                         Aruba
# 1          AFG  Afghanistan  Afghanistan  Islamic State of Afghanistan
# 2          AGO       Angola       Angola   People's Republic of Angola
# 3          ALB      Albania      Albania           Republic of Albania
# 4          AND      Andorra      Andorra       Principality of Andorra
#
#   2-alpha code   Currency Unit  \
# 0           AW   Aruban florin
# 1           AF  Afghan afghani
# 2           AO  Angolan kwanza
# 3           AL    Albanian lek
# 4           AD            Euro
#
#                                        Special Notes  \
# 0  SNA data for 2000-2011 are updated from offici...
# 1  Fiscal year end: March 20; reporting period fo...
# 2  April 2013 database update: Based on IMF data,...
# 3                                                NaN
# 4  The base year has changed to 2000. Price valua...
#
# ...

# %%
cityTemp.head()
# Out:
#            dt  AverageTemperature  AverageTemperatureUncertainty   City  \
# 0  1743-11-01               6.068                          1.737  Århus
# 1  1743-12-01                 NaN                            NaN  Århus
# 2  1744-01-01                 NaN                            NaN  Århus
# 3  1744-02-01                 NaN                            NaN  Århus
# 4  1744-03-01                 NaN                            NaN  Århus
#
#    Country Latitude Longitude
# 0  Denmark   57.05N    10.33E
# 1  Denmark   57.05N    10.33E
# 2  Denmark   57.05N    10.33E
# 3  Denmark   57.05N    10.33E
# 4  Denmark   57.05N    10.33E

# %%
stateTemp.head()
# Out:
#            dt  AverageTemperature  AverageTemperatureUncertainty State Country
# 0  1855-05-01              25.544                          1.171  Acre  Brazil
# 1  1855-06-01              24.228                          1.103  Acre  Brazil
# 2  1855-07-01              24.371                          1.044  Acre  Brazil
# 3  1855-08-01              25.427                          1.073  Acre  Brazil
# 4  1855-09-01              25.675                          1.014  Acre  Brazil

# %%
uStates = stateTemp[stateTemp['Country'] == 'United States']
uStates['State'].value_counts()
# Out:
# West Virginia           3239
# Maryland                3239
# Illinois                3239
# Florida                 3239
# District Of Columbia    3239
# Iowa                    3239
# Minnesota               3239
# Georgia (State)         3239
# Ohio                    3239
# Delaware                3239
# New Hampshire           3239
# South Carolina          3239
# North Carolina          3239
# New Jersey              3239
# Kentucky                3239
# Rhode Island            3239
# Missouri                3239
# Wisconsin               3239
# Connecticut             3239
# Vermont                 3239
# Virginia                3239
# Pennsylvania            3239
# Maine                   3239
# Indiana                 3239
# New York                3239
# Michigan                3239
# Massachusetts           3239
# Tennessee               3239
# Alabama                 3239
# Arkansas                3067
# Mississippi             3067
# Louisiana               3067
# ...

# %%
cityTemp['Country'].unique()
# Out:
# array(['Denmark', 'Turkey', 'Kazakhstan', 'China', 'Spain', 'Germany',
#        'Nigeria', 'Iran', 'Russia', 'Canada', "Côte D'Ivoire",
#        'United Kingdom', 'Saudi Arabia', 'Japan', 'United States', 'India',
#        'Benin', 'United Arab Emirates', 'Mexico', 'Venezuela', 'Ghana',
#        'Ethiopia', 'Australia', 'Yemen', 'Indonesia', 'Morocco',
#        'Pakistan', 'France', 'Libya', 'Burma', 'Brazil', 'South Africa',
#        'Syria', 'Egypt', 'Algeria', 'Netherlands', 'Malaysia', 'Portugal',
#        'Ecuador', 'Italy', 'Uzbekistan', 'Philippines', 'Madagascar',
#        'Chile', 'Belgium', 'El Salvador', 'Romania', 'Peru', 'Colombia',
#        'Tanzania', 'Tunisia', 'Turkmenistan', 'Israel', 'Eritrea',
#        'Paraguay', 'Greece', 'New Zealand', 'Vietnam', 'Cameroon', 'Iraq',
#        'Afghanistan', 'Argentina', 'Azerbaijan', 'Moldova', 'Mali',
#        'Congo (Democratic Republic Of The)', 'Thailand',
# ...

# %%
US = cityTemp[cityTemp['Country'] == 'United States']
US['City'].value_counts().sort_index()
# Out:
# Abilene             2325
# Akron               3239
# Albuquerque         2325
# Alexandria          3239
# Allentown           3239
# Amarillo            2325
# Anaheim             1977
# Anchorage           2229
# Ann Arbor           3239
# Antioch             1977
# Arlington           5564
# Arvada              2325
# Atlanta             3239
# Aurora              6101
# Austin              2325
# Bakersfield         1977
# Baltimore           3239
# Baton Rouge         3067
# Beaumont            2325
# Bellevue            2229
# Berkeley            1977
# Birmingham          3239
# Boston              3239
# Bridgeport          3239
# Brownsville         2289
# Buffalo             3239
# Burbank             1977
# Cambridge           3239
# Cape Coral          3067
# Carrollton          2325
#                     ...
# Tacoma              2229
# Tallahassee         3239
# Tampa               3239
# Tempe               2145
# Thornton            2862
# Thousand Oaks       1977
# ...

# %%
print(len(cityTemp))
# Out:
# 8599212

# %%
lst = [[1, 4, 7], [2, 5, 8], [3, 6, 9]]
# list(map(list, zip(lst)))
nlist = np.asarray(lst).T.tolist()
print(lst)
print(nlist)
# Out:
# [[1, 4, 7], [2, 5, 8], [3, 6, 9]]
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
cityTempAvg = cityTemp.groupby('City').mean().reset_index(drop=False)
cityTempAvg.head()

# %%
lat = cityTempAvg['Lat'].values
lon = cityTempAvg['Lon'].values
temp = cityTempAvg['AverageTemperature'].values

# %%
# set up orthographic map projection with
# perspective of satellite looking down at 50N, 100W.
# use low resolution coastlines.
amap = Basemap(projection='robin',lat_0=0,lon_0=-100,resolution='l')

amap.drawmapboundary(fill_color='lgith')
# draw coastlines, country boundaries, fill continents.
amap.drawcoastlines(linewidth=0.25)
amap.drawcountries(linewidth=0.25)
amap.fillcontinents(color='white',zorder=0)

amap.drawmeridians(np.arange(0, 360, 30))
amap.drawparallels(np.arange(-90, 90, 30))

# lat = 57.05
# lon = 10.33

x,y = amap(lon, lat)
# amap.plot(x, y, 'bo', markersize=5)
amap.scatter(x, y, c=temp, cmap='coolwarm')
# amap.hexbin(x,y,gridsize=20, mincnt=1,cmap='coolwarm')
# colors_cw = sns.color_palette('coolwarm', len(countries))
plt.show()
