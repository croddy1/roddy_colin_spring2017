# %% [markdown]
# # Question 1 Part 2
# - For each borough, find out distribution of each collision scale. (One car involved? Two? Three? or more?) (From 2015 to present)

# %%
import pandas as pd
from pandas import DataFrame
import sys, os, datetime

# %%
#Read in data
dataPath = os.getcwd()+'/Data/vehicle_collisions.csv'
df = pd.read_csv(dataPath)

# %%
df['BOROUGH'].fillna('UNRECORDED',inplace=True)
bos = df['BOROUGH'].unique()

# %%
# Out:
# Index(['UNIQUE KEY', 'DATE', 'TIME', 'BOROUGH', 'ZIP CODE', 'LATITUDE',
#        'LONGITUDE', 'LOCATION', 'ON STREET NAME', 'CROSS STREET NAME',
#        'OFF STREET NAME', 'PERSONS INJURED', 'PERSONS KILLED',
#        'PEDESTRIANS INJURED', 'PEDESTRIANS KILLED', 'CYCLISTS INJURED',
#        'CYCLISTS KILLED', 'MOTORISTS INJURED', 'MOTORISTS KILLED',
#        'VEHICLE 1 TYPE', 'VEHICLE 2 TYPE', 'VEHICLE 3 TYPE', 'VEHICLE 4 TYPE',
#        'VEHICLE 5 TYPE', 'VEHICLE 1 FACTOR', 'VEHICLE 2 FACTOR',
#        'VEHICLE 3 FACTOR', 'VEHICLE 4 FACTOR', 'VEHICLE 5 FACTOR'],
#       dtype='object')

# %%
df.head()
# Out:
#    UNIQUE KEY    DATE  TIME     BOROUGH  ZIP CODE   LATITUDE  LONGITUDE  \
# 0     3146911  1/1/15  0:20      QUEENS   11358.0  40.751847 -73.787862
# 1     3146180  1/1/15  0:20  UNRECORDED       NaN  40.771289 -73.946693
# 2     3146384  1/1/15  0:21    BROOKLYN   11205.0  40.689445 -73.955121
# 3     3146013  1/1/15  0:30    BROOKLYN   11213.0  40.673845 -73.925080
# 4     3146120  1/1/15  0:33  UNRECORDED       NaN        NaN        NaN
#
#                     LOCATION    ON STREET NAME   CROSS STREET NAME  \
# 0   (40.7518471, -73.787862)         47 AVENUE          193 STREET
# 1  (40.7712888, -73.9466928)               NaN                 NaN
# 2  (40.6894449, -73.9551212)    BEDFORD AVENUE    LAFAYETTE AVENUE
# 3  (40.6738445, -73.9250801)    BUFFALO AVENUE  SAINT MARKS AVENUE
# 4                        NaN  RICHMOND TERRACE        SOUTH AVENUE
#
#         ...                      VEHICLE 1 TYPE     VEHICLE 2 TYPE  \
# ...

# %%
df['VEHICLES INVOLVED'] = df['VEHICLE 1 TYPE'] + df['VEHICLE 2 TYPE']
df.head()
# Out:
#    UNIQUE KEY    DATE  TIME     BOROUGH  ZIP CODE   LATITUDE  LONGITUDE  \
# 0     3146911  1/1/15  0:20      QUEENS   11358.0  40.751847 -73.787862
# 1     3146180  1/1/15  0:20  UNRECORDED       NaN  40.771289 -73.946693
# 2     3146384  1/1/15  0:21    BROOKLYN   11205.0  40.689445 -73.955121
# 3     3146013  1/1/15  0:30    BROOKLYN   11213.0  40.673845 -73.925080
# 4     3146120  1/1/15  0:33  UNRECORDED       NaN        NaN        NaN
#
#                     LOCATION    ON STREET NAME   CROSS STREET NAME  \
# 0   (40.7518471, -73.787862)         47 AVENUE          193 STREET
# 1  (40.7712888, -73.9466928)               NaN                 NaN
# 2  (40.6894449, -73.9551212)    BEDFORD AVENUE    LAFAYETTE AVENUE
# 3  (40.6738445, -73.9250801)    BUFFALO AVENUE  SAINT MARKS AVENUE
# 4                        NaN  RICHMOND TERRACE        SOUTH AVENUE
#
#              ...                VEHICLE 2 TYPE  VEHICLE 3 TYPE  \
# ...

# %%
vehicles = df.loc[:,'VEHICLE 1 TYPE':'VEHICLE 5 TYPE']
#vehicles.head()
#vehicles.head()
#df.loc[:,'VEHICLE 1 TYPE':'VEHICLE 5 TYPE'].sum(axis=1)
# Out:
# <bound method NDFrame.notnull of                      VEHICLE 1 TYPE               VEHICLE 2 TYPE  \
# 0       SPORT UTILITY/STATION WAGON                          NaN
# 1                 PASSENGER VEHICLE                          NaN
# 2                 PASSENGER VEHICLE                      UNKNOWN
# 3                               BUS            PASSENGER VEHICLE
# 4                           UNKNOWN            PASSENGER VEHICLE
# 5                 PASSENGER VEHICLE  SPORT UTILITY/STATION WAGON
# 6                 PASSENGER VEHICLE            PASSENGER VEHICLE
# 7                 PASSENGER VEHICLE            PASSENGER VEHICLE
# 8                 PASSENGER VEHICLE                          NaN
# 9                 PASSENGER VEHICLE            PASSENGER VEHICLE
# 10                PASSENGER VEHICLE            PASSENGER VEHICLE
# 11      SPORT UTILITY/STATION WAGON                      UNKNOWN
# 12                             TAXI            PASSENGER VEHICLE
# ...

# %%
len(df[df['VEHICLE 1 TYPE'].isnull()])
# Out:
# 3955

# %%
len(df)
# Out:
# 477732

# %%
len(df[df['BOROUGH'] == 'MANHATTAN'])
# Out:
# 83602

# %%
df[df['BOROUGH'].isnull()]['BOROUGH'].apply(lambda x : 'UNRECORDED')
# Out:
# 1         UNRECORDED
# 4         UNRECORDED
# 21        UNRECORDED
# 23        UNRECORDED
# 26        UNRECORDED
# 27        UNRECORDED
# 29        UNRECORDED
# 37        UNRECORDED
# 40        UNRECORDED
# 42        UNRECORDED
# 46        UNRECORDED
# 52        UNRECORDED
# 56        UNRECORDED
# 62        UNRECORDED
# 63        UNRECORDED
# 65        UNRECORDED
# 67        UNRECORDED
# 71        UNRECORDED
# 73        UNRECORDED
# 74        UNRECORDED
# 79        UNRECORDED
# 86        UNRECORDED
# 93        UNRECORDED
# 106       UNRECORDED
# 109       UNRECORDED
# 119       UNRECORDED
# 121       UNRECORDED
# 126       UNRECORDED
# 129       UNRECORDED
# 144       UNRECORDED
#              ...
# 477653    UNRECORDED
# 477658    UNRECORDED
# 477659    UNRECORDED
# 477660    UNRECORDED
# 477661    UNRECORDED
# 477662    UNRECORDED
# 477663    UNRECORDED
# 477664    UNRECORDED
# 477670    UNRECORDED
# 477671    UNRECORDED
# 477673    UNRECORDED
# 477674    UNRECORDED
# ...

# %%
df['BOROUGH'].fillna('UNRECORDED',inplace=True)

# %%
df.head()
# Out:
#    UNIQUE KEY    DATE  TIME     BOROUGH  ZIP CODE   LATITUDE  LONGITUDE  \
# 0     3146911  1/1/15  0:20      QUEENS   11358.0  40.751847 -73.787862
# 1     3146180  1/1/15  0:20  UNRECORDED       NaN  40.771289 -73.946693
# 2     3146384  1/1/15  0:21    BROOKLYN   11205.0  40.689445 -73.955121
# 3     3146013  1/1/15  0:30    BROOKLYN   11213.0  40.673845 -73.925080
# 4     3146120  1/1/15  0:33  UNRECORDED       NaN        NaN        NaN
#
#                     LOCATION    ON STREET NAME   CROSS STREET NAME  \
# 0   (40.7518471, -73.787862)         47 AVENUE          193 STREET
# 1  (40.7712888, -73.9466928)               NaN                 NaN
# 2  (40.6894449, -73.9551212)    BEDFORD AVENUE    LAFAYETTE AVENUE
# 3  (40.6738445, -73.9250801)    BUFFALO AVENUE  SAINT MARKS AVENUE
# 4                        NaN  RICHMOND TERRACE        SOUTH AVENUE
#
#         ...                      VEHICLE 1 TYPE     VEHICLE 2 TYPE  \
# ...
